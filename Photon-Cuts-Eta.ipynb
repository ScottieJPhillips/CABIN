# %% [markdown]
# # CABIN: Cuts as Biases in Networks

# %% [markdown]
# ## Importing Data
# ### data_concat
# **data_concat(path, files, tree, features)**
#
# Uses a concatenation loop to return an awkward array of data
# #### Parameters:
# * **path:**
#
#   The data path that your files are apart of.
# * **files:** *list*
#
#   Files located in your path that you want to use.
# * **tree:**
#
#   Name of treename.
# * **features:** *list*
#
#   What features you want to use.
# #### Returns:
# * **data:** *awkward array*
#
#   Shape : \
#   [ 'feat0': [0,1,2,3,...], \
#   [ 'feat1': [0,1,2,3,...], \
#   [ 'feat2': [0,1,2,3,...], \
#   ... \
#   [ 'featN': [0,1,2,3,...]]

# %%
from LearningCutsUtils.Utils import *

filespath="/data/mhance/photons/NTUP_ZLLG/"
filename = [
'mc16e_13TeV/00-03-01/mc16e.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zee.DAOD_EGAM3.e3601_e5984_s3126_r10724_r10726_p3954.root',
'mc16e_13TeV/00-03-01/mc16e.PowhegPythia8EvtGen_AZNLOCTEQ6L1_Zmumu.DAOD_EGAM4.e3601_e5984_s3126_r10724_r10726_p3954.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_140_E_CMS.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_15_35.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_35_70.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_70_140.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_eegamma_LO_pty_7_15.DAOD_EGAM3.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_7_15.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_140_E_CMS.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_15_35.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_35_70.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root',
'mc16e_13TeV/00-03-01/mc16e.Sh_224_NN30NNLO_mumugamma_LO_pty_70_140.DAOD_EGAM4.e7006_e5984_s3126_r10724_r10726_p3956.root'
]
treename = "output"
expressions_for_batch = ['ph.pt','ph.eta','ph.rhad','ph.rhad1','ph.reta','ph.rphi','ph.weta2','ph.eratio','ph.deltae','ph.wstot','ph.fside','ph.w1','ph.truth_pdgId','ph.truth_type','ph.convFlag']

data = data_concat(filespath,filename,treename,expressions_for_batch)

# %% [markdown]
# ### data_mask
# **data_mask(data, energy_range, eta_range)**
#
# Masks data to the energy and eta range that is inputted.
# #### Parameters:
# * **data:** *awkward array*
#
#   Data in the form of an awkward array that has arrays indexed "ph.pt" and "ph.eta".
#
# * **energy_range:** *= (min_energy, max_energy)*
#
#   Lower and upper bounds on energy. Defaults to no bounds.
# * **eta_range:** *= (min_eta, max_eta)*
#
#   Lower and upper bounds on psuedorapidity. Defaults to no bounds.
# #### Returns:
# * **masked_data:** *numpy array*
#
#   Shape : features $\times$ event candidates.

# %%
erange = (15000,100000)
absetarange = (0.,0.8)
masked_data = data_mask(data,erange,absetarange)
# Out:
# This mask includes 1727130 event candidates:

# %% [markdown]
# ### Discriminating Variables:
# There are three broad categories of discriminating variables for photon identi cation that are based
#  on calorimeter information. The first category considers the amount of energy deposited in different
#  layers of the EM and hadronic calorimeters relative to the total cluster energy; the second looks at
#  the profile of the EM shower in the primary (second) sampling layer of the EM calorimeter; and
#  the final looks at the shower profile in the strip layer.
# #### Energy Ratios:
# * $R_{had}$: the ratio of total transverse energy in the hadronic calorimeter (in a $\Delta \eta \times \Delta \phi$ region of $0.24 \times 0.24$ behind the photon cluster) to the transverse energy of the photon cluster.
# * $R_{had_{1}}$: the ratio of total transverse energy in the first sampling layer of the hadronic calorimeter (in a $\Delta \eta \times \Delta \phi$ region of $0.24 \times 0.24$ behind the photon cluster) to the transverse energy of the photon cluster.
# $R_{had}$ is only considered for $ 0.8 \leq |\eta| < 1.37$ (where the hadronic calorimeter
#  transitions from the barrel to the extended barrel). $R_{had_{1}}$ is considered for all other $\eta$.
# #### Layer-2 Variables:
# * $w_2$: Lateral width of the shower in $\eta$ over a region of $3\times 5$ cells in $\Delta \eta \times \Delta \phi$  around the center of the photon cluster. It is defined as:
# $$ w_{2} = \sqrt{   \frac{\sum E_i \eta_i^2}{E_i} - \left[\frac{\sum E_i \eta_i}{E_i}\right]^2}$$
# where $i$ indicates the cell index, ranging from 0 to 14.
#
# * $R_{\eta}$ The spread in $\eta$ of the energy outside the cluster. Defined as:
# $$ R_{\eta} = \frac{E_{3 \times 7}^{S2}}{E_{7 \times 7}^{S2}}$$
# where $E_{x \times y}^{S2}$ is the energy contained in $x \times y$ cells ($\eta \times \phi$) of the second layer, centerd on the cluster used to define the photon.
#
#
# * $R_{\phi}$ The spread in $\phi$ of the energy within (and outside of) the cluster. Defined as:
# $$ R_{\phi} = \frac{E_{3 \times 3}^{S2}}{E_{7 \times 7}^{S2}}$$
# where $E_{x \times y}^{S2}$ is defined as it is for $R_{\eta}$.
#
# #### Strip Variables:
# * $F_{side}$: The spread in the lateral spread in $\eta$ of the shower. It is defined as:
# $$ F_{side} = \frac{E_{7 \times 1}^{S1} - E_{3 \times 1}^{S1}}{E_{7 \times 1}^{S1}}$$
# where $E_{x \times y}^{S1}$ are the $x \times y$ ($\eta \times \phi$) strips surrounding the strip with the largest energy.
#
# * $w_{s,3}$: The weighted shower width in $\eta$ in the three strips. It is defined as:
# $$ w_{s,3} = \sqrt{\frac{\sum E_{i}(i-i_{max})^2}{\sum E_{i}}}$$
# where $i$ corresponds to the strip number, and $i_{max}$ is index of the strip with the largest energy.
#
# * $w_{s,tot}$: Identical to $w_{s,3}$, except it is measured over all strips in a region of $\Delta \eta \times \Delta \phi = 0.0625 \times .2$ (20 $\times$ 2 strips).
#
# * $\Delta E$: Attempts to quantify the degree to whcih there are two peaks present in the energy profile. It is defined as:
# $$ \Delta E = \left[E_{max2}^{S1} - E_{min}^{S1}\right]$$
# where $E_{max2}^{S1}$ is the energy of the strip that has the second greatest energy, and $E_{min}^{S1}$ is the energy of the strip with the least energy found between the strips with the greatest and second greatest energies. For candidates without a distinguishable second peak, this value is close to zero, while candidates with two peaks in the strips have some larger value.
#
# * $E_{ratio}$ The size of the second maximim relative to the size of the first maximum. It is defined as:
#
# $$ E_{ratio} = \frac{E_{max1}^{S1} - E_{max2}^{S1}}{E_{max1}^{S1} + E_{max2}^{S1}} $$
#
# Distributions for all discriminating videos are generated below for the selected datasets used.

# %%
plot_feats(masked_data)

# %% [markdown]
# ### Preselection of Converted Signal Photons

# %% [markdown]
# ### get_labels
# **get_labels(data)**
#
# Checks if each event candidate is predetermined to be signal or backround.
# #### Parameters:
# * **data:** *numpy array*
#
#   Data has features labeled 'ph.truth_pdgId' and 'ph.truth_type'.
#
#   ```
#   if d['ph.truth_pdgId'][i] == 22 and \
#   d['ph.truth_type'][i]==15 or \
#   d['ph.truth_type'][i]==13 or \
#   d['ph.truth_type'][i]==14:
#       labels.append(1)
#   else:
#       labels.append(0)
#   labels = torch.Tensor(labels) ```
#
# #### Returns:
# * **labels:** *torch tensor*
#
#   Shape : 1 $\times$ event candidates.

# %%
signal_labels = get_labels(masked_data)

# %% [markdown]
# ### true_sort
# **true_sort(data,labels)**
#
# Checks if each event candidate is predetermined to be signal or backround.
# #### Parameters:
# * **data:** *numpy array*
# * **labels** *torch tensor*
#
#   ```
#   if labels[i] == 1:
#       signal.append(data[i])
#   else:
#       backround.append(data[i])
#   ```
#
# #### Returns:
# * **signal:** *numpy array*
#
#   Shape : len(discriminating_vars) $\times$  signal event candidates.
# * **background:** *numpy array*
#
#   Shape : len(discriminating_vars) $\times$  background event candidates.

# %%
signal, backround = true_sort(masked_data,signal_labels)
# Out:
# We are working with:
# 1065034 Signal Events
# 662096 Backround Events
# Signal:Backround = 1.609

# %% [markdown]
# ### Plotting True Vs Untrue Features for Conv

# %%
plot_signal(signal,backround)

# %% [markdown]
# ## Network Architecture
#
# #### Input Tensor:
# Let $X$ represent our input tensor that has shape $N\times F$:
# $$ X \in \mathbb{R}^{N\times F} $$
# Where $N$ is the number of event candidates and $F$ is the number of features.
#
# #### Linear Transform:
# The network computes this as:
#
# $$ T = X \cdot W^{diag} + b $$
#
# Where:
# * $ W \in \mathbb{R}^F $ weight vector (one weight per feature)
# * $ W^{diag} \in \mathbb{R}^{F\times F}$ weight matrix, diagnal matrix of $W$
# $$ W^{diag} = \begin{pmatrix}
# w_1 & 0 & 0 & \cdots & 0 \\
# 0 & w_2 & 0 & \cdots & 0 \\
# 0 & 0 & w_2 & \cdots & 0 \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & 0 & \cdots & w_F
# \end{pmatrix}$$
# * $ b \in \mathbb{R}^F $
#
# #### To be cont.

# %%
import torch
import torch.nn
import torch.optim
import torch.utils.data

import time
import math

# %%
from LearningCutsUtils.OneToOneLinear import OneToOneLinear
from LearningCutsUtils.PtScanNetwork import PtScanNetwork
from LearningCutsUtils.LossFunctions import lossvars, loss_fn, effic_loss_fn

# %%
split_ratio = 0.25
eta_ranges = [(0.0,0.6),(0.6,1.37)]

def test_train_split(d,eta,ratio):

    

    data_bucket = {i: [] for i in range(len(eta))}
    label_bucket = {i: [] for i in range(len(eta))}
    dlist = ['ph.rhad1', 'ph.reta', 'ph.rphi', 'ph.weta2', 'ph.eratio', 'ph.deltae', 'ph.wstot', 'ph.fside', 'ph.w1']
    loosetrues = []
    for i in range(len(d['ph.pt'])):
        if d['ph.truth_pdgId'][i] == 22 and (d['ph.truth_type'][i]==15 or 
                                             d['ph.truth_type'][i]==13 or
                                             d['ph.truth_type'][i]==14):
            true = 1
        else:
            true = 0
        
        for j in range(len(eta)):
            if d['ph.eta'][i] >= eta[j][0] and d['ph.eta'][i] < eta[j][1]:

                label_bucket[j].append(true)
                data_bucket[j].append([d[key][i] for key in dlist])
                break

    loosetrues = torch.Tensor(loosetrues)
    
    x_train_tensor_list = {}
    x_test_tensor_list = {}
    y_train_tensor_list = {}
    y_test_tensor_list = {}
    
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import StandardScaler
    
    for i in range(len(eta)):
        print(len(data_bucket[i]))
        if len(data_bucket[i]) == 0:
            continue

        X = np.array(data_bucket[i], dtype=np.float32)
        Y = np.array(label_bucket[i], dtype=np.float32)
        X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=ratio, random_state=42)
        
    
        sc = StandardScaler()
        
        X_train = sc.fit_transform(X_train)
        X_test = sc.transform(X_test)
        
        x_train_tensor_list[i] = torch.tensor(X_train, dtype=torch.float).detach()
        y_train_tensor_list[i] = torch.tensor(y_train, dtype=torch.float).detach()
        
        x_test_tensor_list[i] = torch.tensor(X_test, dtype=torch.float).detach()
        y_test_tensor_list[i] = torch.tensor(y_test, dtype=torch.float).detach()
        
    return x_train_tensor_list, y_train_tensor_list, x_test_tensor_list, y_test_tensor_list

x_train, y_train, x_test, y_test = test_train_split(masked_data,eta_ranges,split_ratio)
print(len(x_train))
# Out:
# 653429
# 214290
# 2

# %%
from LearningCutsUtils.OneToOneLinear import OneToOneLinear
from LearningCutsUtils.PtScanNetwork import PtScanNetwork
from LearningCutsUtils.LossFunctions import lossvars, loss_fn
from LearningCutsUtils.LossFuncForPT import pt_loss_fn

# %%
N=len(signal_labels) # number of points
m=9 # dimensions

# %%
gt=1.
lt=-1.
cuts_gt_lt = [lt, gt, gt, lt, gt, ### change these to correct cuts
              lt, lt, lt, lt] # l g g l g l l l l

# %%
# some hyperparameters
activation_input_scale_factor=15
learning_rate=0.5
# batch_size=int(len(y_train)/1.) # only one batch
epochs=50
alpha=10.   # scaling factor to tune how important hitting the target signal efficiency is
beta=0.1     # scaling factor to tune how important background rejection is
gamma=1e-5  # scaling factor for how aggressively to push the cuts to zero
delta=0.
epsilon=1e-0   # how much to penalize deviations

# %%
torch.manual_seed(123)

net = PtScanNetwork(m,eta_ranges,cuts_gt_lt,activation_input_scale_factor) # will take m inputs, return m*n_eff outputs
torch.save(net.state_dict(), 'net_learningbiases_pttarget_untrained.pth')

optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate)

# %%
device="cpu"
if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True
    device="cuda:0"
print(device)
# Out:
# cpu

# %%
import importlib
import LearningCutsUtils.PtScanNetwork
import LearningCutsUtils.LossFuncForPT
importlib.reload(LearningCutsUtils.PtScanNetwork)
importlib.reload(LearningCutsUtils.LossFuncForPT)
from LearningCutsUtils.PtScanNetwork import PtScanNetwork
from LearningCutsUtils.LossFuncForPT import *

# %%
importlib.reload(LearningCutsUtils.LossFunctions)
import sys
importlib.reload(sys.modules['LearningCutsUtils'])
from LearningCutsUtils.LossFunctions import loss_fn




losses = []
losses_test = []

net.load_state_dict(torch.load('net_learningbiases_pttarget_untrained.pth',weights_only=True))

debug=False

for epoch in range(epochs):
    net.train()
    start_time = time.time()
    y_pred = net(x_train)
    optimizer.zero_grad()
    loss = pt_loss_fn(y_pred, y_train, m, net, alpha, beta, gamma, delta, epsilon,debug=debug)
    loss.totalloss().backward()
    optimizer.step()
    losses.append(loss)
    net.eval() # configure the model for evaluation (testing)
    y_pred = net(x_test)
    test_loss = pt_loss_fn(y_pred, y_test, m, net, alpha, beta, gamma, delta, epsilon)
    losses_test.append(test_loss)
    end_time=time.time()
    elapsed_time = end_time - start_time
    print(f"Completed epoch {epoch:2d} in {elapsed_time:4.1f}s, Train loss={loss.totalloss().data:4.1e}, Test loss={test_loss.totalloss().data:4.1e}")

torch.save(net.state_dict(), 'net_learningbiases_pttarget_trained.pth')
# Out:
# Completed epoch  0 in  0.2s, Train loss=4.5e+00, Test loss=5.0e-02
# Completed epoch  1 in  0.3s, Train loss=5.2e-02, Test loss=3.5e-02
# Completed epoch  2 in  0.2s, Train loss=3.6e-02, Test loss=2.8e-02
# Completed epoch  3 in  0.2s, Train loss=2.9e-02, Test loss=2.5e-02
# Completed epoch  4 in  0.3s, Train loss=2.6e-02, Test loss=2.4e-02
# Completed epoch  5 in  0.2s, Train loss=2.4e-02, Test loss=2.3e-02
# Completed epoch  6 in  0.2s, Train loss=2.3e-02, Test loss=2.2e-02
# Completed epoch  7 in  0.3s, Train loss=2.3e-02, Test loss=2.2e-02
# Completed epoch  8 in  0.2s, Train loss=2.2e-02, Test loss=2.2e-02
# Completed epoch  9 in  0.2s, Train loss=2.2e-02, Test loss=2.2e-02
# Completed epoch 10 in  0.3s, Train loss=2.2e-02, Test loss=2.2e-02
# Completed epoch 11 in  0.2s, Train loss=2.2e-02, Test loss=2.2e-02
# Completed epoch 12 in  0.2s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 13 in  0.3s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 14 in  0.2s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 15 in  0.2s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 16 in  0.3s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 17 in  0.2s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 18 in  0.3s, Train loss=2.2e-02, Test loss=2.1e-02
# Completed epoch 19 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 20 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 21 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 22 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 23 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 24 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 25 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 26 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 27 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 28 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 29 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 30 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 31 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 32 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 33 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 34 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 35 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 36 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 37 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 38 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 39 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 40 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 41 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 42 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 43 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 44 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 45 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 46 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 47 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 48 in  0.3s, Train loss=2.1e-02, Test loss=2.1e-02
# Completed epoch 49 in  0.2s, Train loss=2.1e-02, Test loss=2.1e-02

# %%
plotlosses(losses,losses_test)

# %%
sig_effics=[]
bkg_effics=[]
loss_sig_effics=[]
loss_bkg_effics=[]

for n in range(len(eta_ranges)):
    print(f"Pt: {eta_ranges[n]}")
    check_effic(x_test[n],y_test[n].numpy(),net.nets[n],True)
    sig_effic,bkg_effic = check_effic(x_test[n],y_test[n].numpy(),net.nets[n],False)
    sig_effics.append(sig_effic)
    bkg_effics.append(bkg_effic)
    
    # check that after reloading the weights we still get the same performance after pretraining
    net.nets[n].eval() # configure the model for evaluation (testing)
    y_pred = net.nets[n](x_test[n])
    test_loss = pt_loss_fn(y_pred[n], y_test[n], m, net.nets[n], eta_ranges[n], alpha, beta, gamma, True)
    print("------------")
    loss_sig_effics.append(test_loss.signaleffic.detach().numpy())
    loss_bkg_effics.append(test_loss.backgreffic.detach().numpy())

# aisf changes effic
# Out:
# Pt: (0.0, 0.6)
# Signal     efficiency with net outputs: 80.8%
# Background efficiency with net outputs: 10.36707%
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 16
#      14 net.nets[n].eval() # configure the model for evaluation (testing)
#      15 y_pred = net.nets[n](x_test[n])
# ---> 16 test_loss = pt_loss_fn(y_pred[n], y_test[n], m, net.nets[n], eta_ranges[n], alpha, beta, gamma, True)
#      17 print("------------")
#      18 loss_sig_effics.append(test_loss.signaleffic.detach().numpy())
#
# File ~/NN-For-Cuts/LearningCutsUtils/LossFuncForPT.py:11, in pt_loss_fn(y_pred, y_true, features, net, alpha, beta, gamma, delta, epsilon, debug)
#       6 def pt_loss_fn(y_pred, y_true, features, net,
#       7                   alpha=1., beta=1., gamma=0.001, delta=0., epsilon=0.001,
#       8                   debug=False):
#      10     sumptlosses=None
# ---> 11     for i in range(len(net.pt)):
#      12         pt=net.pt[i][0]
#      13         ptnet = net.nets[i]
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1729, in Module.__getattr__(self, name)
#    1727     if name in modules:
#    1728         return modules[name]
# -> 1729 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'OneToOneLinear' object has no attribute 'pt'

# %%
import matplotlib.pyplot as plt

plt.plot(targeteffics,targeteffics   , '-', label="Target Efficiency")
plt.plot(targeteffics,sig_effics     , '.', label="Signal effic: cuts")
plt.plot(targeteffics,loss_sig_effics, '.', label="Signal effic: loss")
plt.plot(targeteffics,bkg_effics     , '.', label="Backgr effic: cuts")
plt.plot(targeteffics,loss_bkg_effics, '.', label="Backgr effic: loss")
plt.legend()
plt.xlabel('Target Signal Efficiency')
plt.ylabel('Efficiency')
plt.grid()
#plt.yscale('log');

# %%
# Distributions of cuts
plotcuts(net)
